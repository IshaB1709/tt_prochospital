# %%
# %sql
CREATE SCHEMA IF NOT EXISTS audits; 
CREATE TABLE IF NOT EXISTS audits.load_logs (
    data_source STRING,
    tablename STRING,
    numberofrowscopied INT,
    watermarkcolumnname STRING,
    loaddate TIMESTAMP
);

# %%
# %sql
truncate table audits.load_logs;

# %%
# %sql
select * from audits.load_logs;
